# %%
#my_list = list[]
import requests
import pandas as pd

url = "https://api.openweathermap.org/data/2.5/weather?"
city = "Kolkata"
api_key = "668a5f49c34b15d1d2b99752b28683bf"
com_url = url + "q=" + city + "&appid=" + api_key

payload={}
headers = {}

response = requests.request("GET", com_url, headers=headers, data=payload)

print(response.text)
# Out:
# {"coord":{"lon":88.3697,"lat":22.5697},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50n"}],"base":"stations","main":{"temp":301.12,"feels_like":306.63,"temp_min":301.12,"temp_max":301.12,"pressure":1002,"humidity":89},"visibility":3500,"wind":{"speed":2.06,"deg":150},"clouds":{"all":40},"dt":1656094680,"sys":{"type":1,"id":9114,"country":"IN","sunrise":1656026600,"sunset":1656075256},"timezone":19800,"id":1275004,"name":"Kolkata","cod":200}

# %%
import requests

url = "https://api.openweathermap.org/data/2.5/weather?q=Kolkata&appid=668a5f49c34b15d1d2b99752b28683bf"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

# %%
import pandas as pd
df = pd.read_excel("C:/Users/admin/OneDrive - BizViz Technologies Pvt Ltd/Desktop/Python Scripts/api.xlsx")

df = [df]
df
# Out:
# [        City
#  0    Kolkata
#  1     Mumbai
#  2  Bengaluru
#  3      Surat
#  4  Hyderabad
#  5   Durgapur
#  6   Nabadwip
#  7     Jaipur
#  8       Agra]

# %%
we = []
import requests
import json
import pandas as pd
def weather(city):
    #for c in city:
    city = "Kolkata"
    url = "https://api.openweathermap.org/data/2.5/weather?"
        
    api_key = "668a5f49c34b15d1d2b99752b28683bf"
    com_url = url + "q=" + city + "&appid=" + api_key
    payload={}
    headers = {}
    response = requests.request("GET", com_url, headers=headers, data=payload)
    res =json.loads(response.text)
    we.append(res)
    return[we]

# %%
import pandas as pd
df = pd.read_excel("C:/Users/admin/OneDrive - BizViz Technologies Pvt Ltd/Desktop/Python Scripts/api.xlsx")

df
# Out:
#         City
# 0    Kolkata
# 1     Mumbai
# 2  Bengaluru
# 3      Surat
# 4  Hyderabad
# 5   Durgapur
# 6   Nabadwip
# 7     Jaipur
# 8       Agra

# %%
list1 = []
import requests
import json
import pandas as pd
def weather(temp):
    for c in temp.City:
        city = str(c)
        url = "https://api.openweathermap.org/data/2.5/weather?"
        
        api_key = "668a5f49c34b15d1d2b99752b28683bf"
        com_url = url + "q=" + city + "&appid=" + api_key
        payload={}
        headers = {}
        response = requests.request("GET", com_url, headers=headers, data=payload)
        res =json.loads(response.text)
        list1.append(res)
    return[list1]

# %%
list1 = []
import requests
import json
import pandas as pd
def weather(temp):
    for c in temp.City:
        city = str(c)
        url = "https://api.openweathermap.org/data/2.5/weather?"
        
        api_key = "668a5f49c34b15d1d2b99752b28683bf"
        com_url = url + "q=" + city + "&appid=" + api_key
        payload={}
        headers = {}
        response = requests.request("GET", com_url, headers=headers, data=payload)
        res =json.loads(response.text)
        list1.append(res)
    return[list1]

# %%
weather(df)
# Out:
# [[{'coord': {'lon': 88.3697, 'lat': 22.5697},
#    'weather': [{'id': 721,
#      'main': 'Haze',
#      'description': 'haze',
#      'icon': '50d'}],
#    'base': 'stations',
#    'main': {'temp': 303.12,
#     'feels_like': 310.12,
#     'temp_min': 303.12,
#     'temp_max': 303.12,
#     'pressure': 1002,
#     'humidity': 89},
#    'visibility': 2000,
#    'wind': {'speed': 4.12, 'deg': 150},
#    'clouds': {'all': 75},
#    'dt': 1656134093,
#    'sys': {'type': 1,
#     'id': 9114,
#     'country': 'IN',
#     'sunrise': 1656113014,
#     'sunset': 1656161666},
#    'timezone': 19800,
#    'id': 1275004,
#    'name': 'Kolkata',
#    'cod': 200},
#   {'coord': {'lon': 72.8479, 'lat': 19.0144},
#    'weather': [{'id': 721,
#      'main': 'Haze',
#      'description': 'haze',
#      'icon': '50d'}],
#    'base': 'stations',
#    'main': {'temp': 302.14,
#     'feels_like': 308.76,
#     'temp_min': 302.14,
#     'temp_max': 303.09,
#     'pressure': 1002,
#     'humidity': 84},
# ...
